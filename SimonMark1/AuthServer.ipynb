# %%
# example of working auth serever

# #!/usr/bin/env python3
# import socketserver, picamera, io, logging, ssl
# from http import server
# import socket
# # from threading import Condition
# # from urllib.parse import parse_qs
# import sys
# import base64

# key = ""
# key = base64.b64encode(bytes("boots:testy", 'utf-8'))
# print(key)


# class Handler(server.BaseHTTPRequestHandler):
#     ''' Main class to present webpages and authentication. '''
#     def do_HEAD(self):
#         print("head")
#         self.send_response(200)
#         self.send_header('Content-type', 'text/html')
#         self.end_headers()

#     def do_AUTHHEAD(self):
#         print("auth")
#         self.send_response(401)
#         self.send_header('WWW-Authenticate', 'Basic realm=\"Test\"')
#         self.send_header('Content-type', 'text/html')
#         self.end_headers()

#     def do_GET(self):
#         global key
#         print("get")
#         ''' Present frontpage with user authentication. '''
#         if self.headers.get('Authorization') == None:
#             self.do_AUTHHEAD()
#             print("in none")
# #             self.wfile.write('no auth header received')
#             pass
#         elif self.headers.get('Authorization') == ("Basic "+ str(key)[2:-1]):
#             self.do_HEAD()
#             print("in auth")
# #             self.wfile.write(self.headers.get('Authorization'))
# #             self.wfile.write('authenticated!')
#             pass
#         else:
#             self.do_AUTHHEAD()
#             print("Basic "+ str(key)[2:-1])
#             print("in other")
#             print(self.headers.get('Authorization'))
# #             self.wfile.write(self.headers.get('Authorization'))
# #             self.wfile.write('not authenticated')
#             pass

# #         httpd = server.TCPServer(("", 10001), Handler)
# httpd = server.HTTPServer(("", 10001), Handler)
# httpd.socket = ssl.wrap_socket (httpd.socket, 
#     certfile="web/CA/server.pem", server_side=True)
# httpd.serve_forever()

# if __name__ == '__main__':
#     main()
