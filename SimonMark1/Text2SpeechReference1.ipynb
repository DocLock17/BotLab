# %%
# sudo apt-get update && sudo apt-get install espeak
# !pip install pyttsx3
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('voice', 'en-scottish')
engine.setProperty('rate', 90)
engine.say("The same thing we do everyday, jameetuh, try and take over the world!")
# engine.runAndWait()
# engine.setProperty('rate', 130)
# engine.say("how are you")
# engine.setProperty('rate', 90)
# engine.say("Hello, My name is Simen. It's nice too meet you Jameetuh! Would you like to fuck?")
engine.runAndWait()

# %%
import pyttsx3
# engine = pyttsx3.init()
engine.setProperty('voice', 'en-scottish')
# engine.setProperty('rate', 90 - 160)
engine.setProperty('rate',110)
engine.say("Good Morning Kylee! Did you sleep well?")
engine.runAndWait()

# %%
import pyttsx3
# engine = pyttsx3.init()
engine.setProperty('voice', 'en-scottish')
# engine.setProperty('rate', 90 - 160)
engine.setProperty('rate',110)
engine.say("Good evening Michael! What shall we work on next?")
engine.say("Good evening Michael! What will we be working on next?")
engine.runAndWait()

# %%
# import pyttsx3
# engine = pyttsx3.init()
# voices = engine.getProperty('voices')
# for voice in voices:
#    print("Using voice:", voice)
#    engine.setProperty('voice', voice.id)
#    engine.say('The quick brown fox jumped over the lazy dog.')
# engine.runAndWait()

# %%
# import pyttsx3
# engine = pyttsx3.init()

# engine.setProperty('voice', 'english')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()
                   
# engine.setProperty('voice', 'en-scottish')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'irish-gaeilge')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'english-north')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'english_rp')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'english_wmids')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'en-westindies')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'english-us')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'czech')
# engine.setProperty('rate', 140)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'russian')
# engine.setProperty('rate', 120)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'romanian')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'italian')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()



# engine.setProperty('voice', 'french')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'crotian')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()

# engine.setProperty('voice', 'welsh')
# engine.setProperty('rate', 90)
# engine.say("would you like to fuck?")
# engine.runAndWait()
# engine.say("Good Morning Kylee! Did you sleep well?")

# %%
import pyttsx3
engine = pyttsx3.init()
engine.setProperty('voice', 'en-scottish')

engine.setProperty('rate',110)
engine.say("Bu!")
engine.runAndWait()
engine.setProperty('rate', 110)
engine.say("Ha ha ha ha")
engine.runAndWait()
engine.setProperty('rate', 110)
engine.say("Happy Halloween Kylee!")
engine.runAndWait()
engine.setProperty('rate', 110)
engine.say("Did you sleep well?")
engine.runAndWait()

# %%
#.txt file reader
story = open("THECRABANDTHEHERON.txt", "r")
storyText = ''
finalText = ''
for eachLine in story:
    sentences = eachLine.splitlines()      
#     print(sentences)
    engine.say(sentences)
    engine.runAndWait()
